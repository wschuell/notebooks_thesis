# %%
from settings import meta_exp
from settings import plt_settings
plt_settings()

# %%
meta_exp.run_single(batch='nobatch')

# %%
meta_exp.run(batch='avakas')
# Out:
# [2018 06 14 18:13:27]: Queue updated
#     total: 11
#     running: 8
#     script error: 3
#
#     execution time: 15 days 18 h 28 min 28.607269525527954 s
#     jobs done: 600
#     jobs restarted: 0
#     jobs extended: 1010

# %%
for m in ['srtheo','Nlink','N_d']:
    meta_exp.plot(measure=m,vu_type='all',M=40,N=100,loglog=False)

# %%
for m in ['conv_time','max_mem','max_N_d']:
    p = meta_exp.plot_against(token='N',measure=m,M='all',loglog=True,get_object=True)
    meta_exp.powerlaw_fit(p)
    p = meta_exp.plot_against(token='M',measure=m,N='all',loglog=True,get_object=True)
    meta_exp.powerlaw_fit(p)

# %%
for m in ['srtheo','Nlink','N_d']:
    meta_exp.plot(measure=m,active=False,biased='all',th=0.8,M=20)
    meta_exp.plot(measure=m,active=True,biased='all',strategy='all',th=0.8,M=20)

# %%
p =     meta_exp.plot(measure='srtheo',vu_type='all',M=20,get_object=True)

# %%
p.loglog=True
p.show()

# %%
meta_exp.xp_cfg(M=20)
# Out:
# {'pop_cfg': {'env_cfg': {'M': 20, 'W': 20, 'env_type': 'simple'},
#   'interact_cfg': {'interact_type': 'speakerschoice'},
#   'nbagent': 20,
#   'strat_cfg': {'strat_type': 'naive', 'vu_cfg': {'vu_type': 'minimal'}},
#   'voc_cfg': {'voc_type': 'matrix_new'}},
#  'step': 'log_improved'}

# %%
plt_settings()
